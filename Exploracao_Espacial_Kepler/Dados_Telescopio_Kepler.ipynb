# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

# %% [markdown]
# ---

# %% [markdown]
# ### Links importantes
#
# - https://exoplanetarchive.ipac.caltech.edu/docs/data.html
# - https://exoplanetarchive.ipac.caltech.edu/docs/API_kepcandidate_columns.html (significado das colunas)
# - https://exoplanets.nasa.gov/search-for-life/can-we-find-life/
# - https://www.centauri-dreams.org/2015/01/30/a-review-of-the-best-habitable-planet-candidates/
# - https://phl.upr.edu/projects/habitable-exoplanets-catalog
#
#
# ### O que é um exoplaneta:
#
# - https://brasilescola.uol.com.br/geografia/exoplanetas.htm

# %% [markdown]
# ---

# %%
kepler = pd.read_csv('kepler.csv', header = 53)
kepler
# Out:
#          kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# 0     10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 1     10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 2     10811496  K00753.01           NaN       CANDIDATE        CANDIDATE
# 3     10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4     10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
# ...        ...        ...           ...             ...              ...
# 9559  10090151  K07985.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 9560  10128825  K07986.01           NaN       CANDIDATE        CANDIDATE
# 9561  10147276  K07987.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 9562  10155286  K07988.01           NaN       CANDIDATE        CANDIDATE
# 9563  10156110  K07989.01           NaN  FALSE POSITIVE   FALSE POSITIVE
#
#       koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# ...

# %%
kepler.info()

# %%
kepler.isnull().sum()

# %%
kepler['koi_disposition'].unique()
# Out:
# array(['CONFIRMED', 'CANDIDATE', 'FALSE POSITIVE'], dtype=object)

# %%
candidatos = kepler[(kepler['koi_disposition'] == 'CONFIRMED') & (kepler['koi_insol'] < 1.11) &
       (kepler['koi_insol'] > 0.36) & (kepler['koi_prad'] < 1.6)]
candidatos
# Out:
#          kepid kepoi_name    kepler_name koi_disposition koi_pdisposition  \
# 2285  11768142  K02626.01  Kepler-1652 b       CONFIRMED        CANDIDATE
# 2660   3642335  K03010.01  Kepler-1410 b       CONFIRMED        CANDIDATE
# 4636  11497958  K01422.04   Kepler-296 f       CONFIRMED        CANDIDATE
# 4766   4138008  K04742.01   Kepler-442 b       CONFIRMED        CANDIDATE
# 6016  11497958  K01422.05   Kepler-296 e       CONFIRMED        CANDIDATE
# 6020   6444896  K03138.01  Kepler-1649 b       CONFIRMED        CANDIDATE
# 6463   9002278  K00701.04    Kepler-62 f       CONFIRMED        CANDIDATE
# 9014   8311864  K07016.01   Kepler-452 b       CONFIRMED        CANDIDATE
#
#       koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 2285      0.999              0              0              0              0
# 2660      0.996              0              0              0              0
# ...

# %%
candidatos[candidatos['kepler_name'] == 'Kepler-442 b'].T
# Out:
#                               4766
# kepid                      4138008
# kepoi_name               K04742.01
# kepler_name           Kepler-442 b
# koi_disposition          CONFIRMED
# koi_pdisposition         CANDIDATE
# koi_score                    0.993
# koi_fpflag_nt                    0
# koi_fpflag_ss                    0
# koi_fpflag_co                    0
# koi_fpflag_ec                    0
# koi_period              112.303136
# koi_period_err1           0.001722
# koi_period_err2          -0.001722
# koi_time0bk               230.4383
# koi_time0bk_err1            0.0125
# koi_time0bk_err2           -0.0125
# koi_impact                   0.248
# koi_impact_err1              0.191
# koi_impact_err2             -0.248
# koi_duration                 5.869
# koi_duration_err1            0.362
# koi_duration_err2           -0.362
# koi_depth                    502.1
# koi_depth_err1                44.1
# koi_depth_err2               -44.1
# koi_prad                       1.3
# ...
