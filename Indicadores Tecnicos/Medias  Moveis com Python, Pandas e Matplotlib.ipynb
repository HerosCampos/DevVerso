# %% [markdown]
# ### Importando Bibliotecas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

# %% [markdown]
#  - https://pandas-datareader.readthedocs.io/en/latest/
#
#  - https://pandas-datareader.readthedocs.io/en/latest/remote_data.html
#
#  - https://pandas-datareader.readthedocs.io/en/latest/remote_data.html#remote-data-yahoo

# %%
import pandas_datareader
import pandas_datareader.data as web
import datetime

# %% [markdown]
# ---

# %% [markdown]
# ### Material para consulta
#
# - https://proeducacional.com/ead/curso-cga-modulo-i/capitulos/capitulo-4/aulas/medias-moveis-simples-e-exponencial-cruzamento-bandas-de-bollinger/
#
# - https://www.tororadar.com.br/investimento/analise-tecnica/medias-moveis
#
# - https://dvinvest.com.br/aprenda/blog/medias-moveis-aprenda-como-utilizar-as-medias-moveis-para-auxiliar-suas-operacoes

# %%
btc_data = web.get_data_yahoo(['BTC-USD'], 
                          start=datetime.datetime(2018, 1, 1), 
                          end=datetime.datetime(2022, 4, 1))

# %%
btc_data
# Out:
# Attributes     Adj Close         Close          High           Low  \
# Symbols          BTC-USD       BTC-USD       BTC-USD       BTC-USD
# Date
# 2018-01-01  13657.200195  13657.200195  14112.200195  13154.700195
# 2018-01-02  14982.099609  14982.099609  15444.599609  13163.599609
# 2018-01-03  15201.000000  15201.000000  15572.799805  14844.500000
# 2018-01-04  15599.200195  15599.200195  15739.700195  14522.200195
# 2018-01-05  17429.500000  17429.500000  17705.199219  15202.799805
# ...                  ...           ...           ...           ...
# 2022-03-29  47465.730469  47465.730469  48022.289062  47100.437500
# 2022-03-30  47062.664062  47062.664062  47655.148438  46746.210938
# 2022-03-31  45538.675781  45538.675781  47512.027344  45390.539062
# 2022-04-01  46281.644531  46281.644531  46616.242188  44403.140625
# 2022-04-02  46209.609375  46209.609375  47003.429688  45783.277344
#
# Attributes          Open       Volume
# Symbols          BTC-USD      BTC-USD
# Date
# ...

# %%
btc_data['Adj Close'].plot(figsize = (16, 10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
btc2 = btc_data.loc['2021-01': '2022-04'].copy()
btc2
# Out:
# Attributes     Adj Close         Close          High           Low  \
# Symbols          BTC-USD       BTC-USD       BTC-USD       BTC-USD
# Date
# 2021-01-01  29374.152344  29374.152344  29600.626953  28803.585938
# 2021-01-02  32127.267578  32127.267578  33155.117188  29091.181641
# 2021-01-03  32782.023438  32782.023438  34608.558594  32052.316406
# 2021-01-04  31971.914062  31971.914062  33440.218750  28722.755859
# 2021-01-05  33992.429688  33992.429688  34437.589844  30221.187500
# ...                  ...           ...           ...           ...
# 2022-03-29  47465.730469  47465.730469  48022.289062  47100.437500
# 2022-03-30  47062.664062  47062.664062  47655.148438  46746.210938
# 2022-03-31  45538.675781  45538.675781  47512.027344  45390.539062
# 2022-04-01  46281.644531  46281.644531  46616.242188  44403.140625
# 2022-04-02  46209.609375  46209.609375  47003.429688  45783.277344
#
# Attributes          Open       Volume
# Symbols          BTC-USD      BTC-USD
# Date
# ...

# %% [markdown]
# ### Média Móvel Simples

# %%
btc2['SMA30'] = btc2['Close'].rolling(window = 30).mean()
btc2
# Out:
# Attributes     Adj Close         Close          High           Low  \
# Symbols          BTC-USD       BTC-USD       BTC-USD       BTC-USD
# Date
# 2021-01-01  29374.152344  29374.152344  29600.626953  28803.585938
# 2021-01-02  32127.267578  32127.267578  33155.117188  29091.181641
# 2021-01-03  32782.023438  32782.023438  34608.558594  32052.316406
# 2021-01-04  31971.914062  31971.914062  33440.218750  28722.755859
# 2021-01-05  33992.429688  33992.429688  34437.589844  30221.187500
# ...                  ...           ...           ...           ...
# 2022-03-29  47465.730469  47465.730469  48022.289062  47100.437500
# 2022-03-30  47062.664062  47062.664062  47655.148438  46746.210938
# 2022-03-31  45538.675781  45538.675781  47512.027344  45390.539062
# 2022-04-01  46281.644531  46281.644531  46616.242188  44403.140625
# 2022-04-02  46209.609375  46209.609375  47003.429688  45783.277344
#
# Attributes          Open       Volume         SMA30
# ...

# %%
fig = plt.figure(figsize = (14, 8))
ax = fig.add_axes([0, 0, 1, 1])
ax.plot(btc2['Close'], label = 'Bitcoin')
ax.plot(btc2['SMA30'], label = 'SMA30')
ax.plot(btc2['Close'].rolling(window = 15).mean(), label = 'SMA15')

ax.set_title('Bitcoin', fontsize = 20)
ax.set_ylabel('Preço ($)', fontsize = 16)

plt.legend()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### Média Móvel Exponencial

# %% [markdown]
# - https://pandas.pydata.org/pandas-docs/version/0.17.0/generated/pandas.ewma.html
#
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.ewm.html

# %%
btc2['EMA30'] = btc2['Close'].ewm(span = 30).mean()
btc2
# Out:
# Attributes     Adj Close         Close          High           Low  \
# Symbols          BTC-USD       BTC-USD       BTC-USD       BTC-USD
# Date
# 2021-01-01  29374.152344  29374.152344  29600.626953  28803.585938
# 2021-01-02  32127.267578  32127.267578  33155.117188  29091.181641
# 2021-01-03  32782.023438  32782.023438  34608.558594  32052.316406
# 2021-01-04  31971.914062  31971.914062  33440.218750  28722.755859
# 2021-01-05  33992.429688  33992.429688  34437.589844  30221.187500
# ...                  ...           ...           ...           ...
# 2022-03-29  47465.730469  47465.730469  48022.289062  47100.437500
# 2022-03-30  47062.664062  47062.664062  47655.148438  46746.210938
# 2022-03-31  45538.675781  45538.675781  47512.027344  45390.539062
# 2022-04-01  46281.644531  46281.644531  46616.242188  44403.140625
# 2022-04-02  46209.609375  46209.609375  47003.429688  45783.277344
#
# Attributes          Open       Volume         SMA30         EMA30
# ...

# %%
fig = plt.figure(figsize = (14, 8))
ax = fig.add_axes([0, 0, 1, 1])
ax.plot(btc2['Close'], label = 'Bitcoin')
ax.plot(btc2['EMA30'], label = 'EMA30', color = 'navy')
ax.plot(btc2['Close'].ewm(span = 15).mean(), label = 'EMA15', color = 'orange')

ax.set_title('Bitcoin com médias móveis ', fontsize = 20)
ax.set_ylabel('Preço ($)', fontsize = 16)

plt.legend()
plt.show()

# %% [markdown]
# ### Visualizando as duas médias juntas

# %%
btc2[['Close', 'EMA30', 'SMA30']].plot(figsize = (16,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---
