# %% [markdown]
# ### Importando Bibliotecas

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set_style('whitegrid')

# %% [markdown]
# plt.style.use('seaborn')

# %% [markdown]
# plt.style.available

# %% [markdown]
# ### Criando DataFrame

# %%
carros = pd.DataFrame(np.random.randint(3000, 25000, size=(8,12)), 
                   ['Fiat', 'Pegeout', 'Volkswagem', 'Ford', 'Nissan', 'Toyota', 'Honda', 'Chevrolet'], 
                   ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez'],)
carros
# Out:
#               Jan    Fev    Mar    Abr    Mai    Jun    Jul    Ago    Set  \
# Fiat         9010  12156   8030   8855  18181  20524  18287   9715  17724
# Pegeout     13876   6141  11351  14030  12541  10384  17910  15504  11475
# Volkswagem   6024  18034  17542  12640  13601  23627   3498   3939  15367
# Ford        18420  21022  21407   6741   9503  15975  23638  10936  11418
# Nissan       3175   9327  19704   3490  15742   4757  19639   6129  12241
# Toyota      12229  20861  10406  20532  13924   8232  19126  21741   5566
# Honda        5188  23126  12817  11486  23525  14939   8123  13466  18821
# Chevrolet    8227  21870  19001   5024  24894  11669   8013  18035  20497
#
#               Out    Nov    Dez
# Fiat        17014   5080   5801
# Pegeout      8265   7336   5813
# Volkswagem   8502   4892   7318
# Ford         4207  14324  10088
# Nissan      24331  22737  13297
# Toyota       9586  20750   7614
# Honda       20223  12222  16808
# Chevrolet   12423  17169   8641

# %% [markdown]
# ---

# %% [markdown]
# ### Conhecendo as informações do DataFrame

# %%
carros.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, Fiat to Chevrolet
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Jan     8 non-null      int32
#  1   Fev     8 non-null      int32
#  2   Mar     8 non-null      int32
#  3   Abr     8 non-null      int32
#  4   Mai     8 non-null      int32
#  5   Jun     8 non-null      int32
#  6   Jul     8 non-null      int32
#  7   Ago     8 non-null      int32
#  8   Set     8 non-null      int32
#  9   Out     8 non-null      int32
#  10  Nov     8 non-null      int32
#  11  Dez     8 non-null      int32
# dtypes: int32(12)
# memory usage: 448.0+ bytes

# %%
carros.describe()
# Out:
#                 Jan          Fev           Mar           Abr           Mai  \
# count      8.000000      8.00000      8.000000      8.000000      8.000000
# mean    9518.625000  16567.12500  15032.250000  10349.750000  16488.875000
# std     5052.617651   6460.38297   4977.164073   5534.771921   5383.584346
# min     3175.000000   6141.00000   8030.000000   3490.000000   9503.000000
# 25%     5815.000000  11448.75000  11114.750000   6311.750000  13336.000000
# 50%     8618.500000  19447.50000  15179.500000  10170.500000  14833.000000
# 75%    12640.750000  21234.00000  19176.750000  12987.500000  19517.000000
# max    18420.000000  23126.00000  21407.000000  20532.000000  24894.000000
#
#                 Jun           Jul           Ago           Set           Out  \
# count      8.000000      8.000000      8.000000      8.000000      8.000000
# mean   13763.375000  14779.250000  12433.125000  14138.625000  13068.875000
# ...

# %%
# Nomes das Colunas
carros.columns
# Out:
# Index(['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out',
#        'Nov', 'Dez'],
#       dtype='object')

# %%
# Index
carros.index
# Out:
# Index(['Fiat', 'Pegeout', 'Volkswagem', 'Ford', 'Nissan', 'Toyota', 'Honda',
#        'Chevrolet'],
#       dtype='object')

# %% [markdown]
# ### Visualizando colunas

# %%
carros['Fev']
# Out:
# Fiat          12156
# Pegeout        6141
# Volkswagem    18034
# Ford          21022
# Nissan         9327
# Toyota        20861
# Honda         23126
# Chevrolet     21870
# Name: Fev, dtype: int32

# %%
carros[['Fev', 'Jul', 'Nov']]
# Out:
#               Fev    Jul    Nov
# Fiat        12156  18287   5080
# Pegeout      6141  17910   7336
# Volkswagem  18034   3498   4892
# Ford        21022  23638  14324
# Nissan       9327  19639  22737
# Toyota      20861  19126  20750
# Honda       23126   8123  12222
# Chevrolet   21870   8013  17169

# %% [markdown]
# ### Criando novas colunas com informações adicionais

# %%
total_carros = carros.sum(axis = 1)
total_carros
# Out:
# Fiat          150377
# Pegeout       134626
# Volkswagem    134984
# Ford          167679
# Nissan        154569
# Toyota        170567
# Honda         180744
# Chevrolet     175463
# dtype: int64

# %%
carros['Total'] = total_carros
carros
# Out:
#               Jan    Fev    Mar    Abr    Mai    Jun    Jul    Ago    Set  \
# Fiat         9010  12156   8030   8855  18181  20524  18287   9715  17724
# Pegeout     13876   6141  11351  14030  12541  10384  17910  15504  11475
# Volkswagem   6024  18034  17542  12640  13601  23627   3498   3939  15367
# Ford        18420  21022  21407   6741   9503  15975  23638  10936  11418
# Nissan       3175   9327  19704   3490  15742   4757  19639   6129  12241
# Toyota      12229  20861  10406  20532  13924   8232  19126  21741   5566
# Honda        5188  23126  12817  11486  23525  14939   8123  13466  18821
# Chevrolet    8227  21870  19001   5024  24894  11669   8013  18035  20497
#
#               Out    Nov    Dez   Total
# Fiat        17014   5080   5801  150377
# Pegeout      8265   7336   5813  134626
# Volkswagem   8502   4892   7318  134984
# Ford         4207  14324  10088  167679
# Nissan      24331  22737  13297  154569
# Toyota       9586  20750   7614  170567
# ...

# %%
# Adicionando Nacionalidade das Marcas
carros_origem = ['Italia', 'França', 'Alemanha', 'EUA', 'Japão', 'Japão', 'Japão', 'EUA']
carros['Origem'] = carros_origem

# %%
carros
# Out:
#               Jan    Fev    Mar    Abr    Mai    Jun    Jul    Ago    Set  \
# Fiat         9010  12156   8030   8855  18181  20524  18287   9715  17724
# Pegeout     13876   6141  11351  14030  12541  10384  17910  15504  11475
# Volkswagem   6024  18034  17542  12640  13601  23627   3498   3939  15367
# Ford        18420  21022  21407   6741   9503  15975  23638  10936  11418
# Nissan       3175   9327  19704   3490  15742   4757  19639   6129  12241
# Toyota      12229  20861  10406  20532  13924   8232  19126  21741   5566
# Honda        5188  23126  12817  11486  23525  14939   8123  13466  18821
# Chevrolet    8227  21870  19001   5024  24894  11669   8013  18035  20497
#
#               Out    Nov    Dez   Total    Origem
# Fiat        17014   5080   5801  150377    Italia
# Pegeout      8265   7336   5813  134626    França
# Volkswagem   8502   4892   7318  134984  Alemanha
# Ford         4207  14324  10088  167679       EUA
# ...

# %% [markdown]
# ### Organizando da marca mais vendida para a menos vendida

# %%
carros.sort_values(by = 'Total', ascending = False)
# Out:
#               Jan    Fev    Mar    Abr    Mai    Jun    Jul    Ago    Set  \
# Honda        5188  23126  12817  11486  23525  14939   8123  13466  18821
# Chevrolet    8227  21870  19001   5024  24894  11669   8013  18035  20497
# Toyota      12229  20861  10406  20532  13924   8232  19126  21741   5566
# Ford        18420  21022  21407   6741   9503  15975  23638  10936  11418
# Nissan       3175   9327  19704   3490  15742   4757  19639   6129  12241
# Fiat         9010  12156   8030   8855  18181  20524  18287   9715  17724
# Volkswagem   6024  18034  17542  12640  13601  23627   3498   3939  15367
# Pegeout     13876   6141  11351  14030  12541  10384  17910  15504  11475
#
#               Out    Nov    Dez   Total    Origem
# Honda       20223  12222  16808  180744     Japão
# Chevrolet   12423  17169   8641  175463       EUA
# Toyota       9586  20750   7614  170567     Japão
# Ford         4207  14324  10088  167679       EUA
# ...

# %% [markdown]
# ### Removendo colunas e linhas

# %%
carros.drop('Dez', axis = 1)
# Out:
#               Jan    Fev    Mar    Abr    Mai    Jun    Jul    Ago    Set  \
# Fiat         9010  12156   8030   8855  18181  20524  18287   9715  17724
# Pegeout     13876   6141  11351  14030  12541  10384  17910  15504  11475
# Volkswagem   6024  18034  17542  12640  13601  23627   3498   3939  15367
# Ford        18420  21022  21407   6741   9503  15975  23638  10936  11418
# Nissan       3175   9327  19704   3490  15742   4757  19639   6129  12241
# Toyota      12229  20861  10406  20532  13924   8232  19126  21741   5566
# Honda        5188  23126  12817  11486  23525  14939   8123  13466  18821
# Chevrolet    8227  21870  19001   5024  24894  11669   8013  18035  20497
#
#               Out    Nov   Total    Origem
# Fiat        17014   5080  150377    Italia
# Pegeout      8265   7336  134626    França
# Volkswagem   8502   4892  134984  Alemanha
# Ford         4207  14324  167679       EUA
# Nissan      24331  22737  154569     Japão
# ...

# %%
carros.drop('Honda', inplace=True,)

# %%
carros
# Out:
#               Jan    Fev    Mar    Abr    Mai    Jun    Jul    Ago    Set  \
# Fiat         9010  12156   8030   8855  18181  20524  18287   9715  17724
# Pegeout     13876   6141  11351  14030  12541  10384  17910  15504  11475
# Volkswagem   6024  18034  17542  12640  13601  23627   3498   3939  15367
# Ford        18420  21022  21407   6741   9503  15975  23638  10936  11418
# Nissan       3175   9327  19704   3490  15742   4757  19639   6129  12241
# Toyota      12229  20861  10406  20532  13924   8232  19126  21741   5566
# Chevrolet    8227  21870  19001   5024  24894  11669   8013  18035  20497
#
#               Out    Nov    Dez   Total    Origem
# Fiat        17014   5080   5801  150377    Italia
# Pegeout      8265   7336   5813  134626    França
# Volkswagem   8502   4892   7318  134984  Alemanha
# Ford         4207  14324  10088  167679       EUA
# Nissan      24331  22737  13297  154569     Japão
# Toyota       9586  20750   7614  170567     Japão
# ...

# %% [markdown]
# ## Conhecendo valores únicos

# %%
temp = pd.DataFrame(np.random.randint(5, size=(6,6)))
temp
# Out:
#    0  1  2  3  4  5
# 0  3  0  2  2  3  4
# 1  0  4  0  2  3  2
# 2  3  0  0  4  1  3
# 3  2  1  4  1  3  4
# 4  2  3  4  4  1  1
# 5  4  4  4  1  0  4

# %%
temp[0].nunique()
# Out:
# 4

# %%
temp[0].unique()
# Out:
# array([3, 0, 2, 4])

# %% [markdown]
# ### Quantas vezes esses valores apareceram

# %%
temp[0].value_counts()
# Out:
# 2    2
# 3    2
# 0    1
# 4    1
# Name: 0, dtype: int64

# %% [markdown]
# ### Selecionando linhas

# %%
carros
# Out:
#               Jan    Fev    Mar    Abr    Mai    Jun    Jul    Ago    Set  \
# Fiat         9010  12156   8030   8855  18181  20524  18287   9715  17724
# Pegeout     13876   6141  11351  14030  12541  10384  17910  15504  11475
# Volkswagem   6024  18034  17542  12640  13601  23627   3498   3939  15367
# Ford        18420  21022  21407   6741   9503  15975  23638  10936  11418
# Nissan       3175   9327  19704   3490  15742   4757  19639   6129  12241
# Toyota      12229  20861  10406  20532  13924   8232  19126  21741   5566
# Chevrolet    8227  21870  19001   5024  24894  11669   8013  18035  20497
#
#               Out    Nov    Dez   Total    Origem
# Fiat        17014   5080   5801  150377    Italia
# Pegeout      8265   7336   5813  134626    França
# Volkswagem   8502   4892   7318  134984  Alemanha
# Ford         4207  14324  10088  167679       EUA
# Nissan      24331  22737  13297  154569     Japão
# Toyota       9586  20750   7614  170567     Japão
# ...

# %%
# LOC
carros.loc[['Ford']]
# Out:
#         Jan    Fev    Mar   Abr   Mai    Jun    Jul    Ago    Set   Out  \
# Ford  18420  21022  21407  6741  9503  15975  23638  10936  11418  4207
#
#         Nov    Dez   Total Origem
# Ford  14324  10088  167679    EUA

# %%
# LOC - Selecionando linhas e colunas específicas
carros.loc[['Nissan', 'Pegeout', 'Toyota'], ['Fev', 'Jun']]
# Out:
#            Fev    Jun
# Nissan    9327   4757
# Pegeout   6141  10384
# Toyota   20861   8232

# %%
# ILOC
carros.iloc[[3]]
# Out:
#         Jan    Fev    Mar   Abr   Mai    Jun    Jul    Ago    Set   Out  \
# Ford  18420  21022  21407  6741  9503  15975  23638  10936  11418  4207
#
#         Nov    Dez   Total Origem
# Ford  14324  10088  167679    EUA

# %%
# ILOC - range
carros.iloc[3:6]
# Out:
#           Jan    Fev    Mar    Abr    Mai    Jun    Jul    Ago    Set    Out  \
# Ford    18420  21022  21407   6741   9503  15975  23638  10936  11418   4207
# Nissan   3175   9327  19704   3490  15742   4757  19639   6129  12241  24331
# Toyota  12229  20861  10406  20532  13924   8232  19126  21741   5566   9586
#
#           Nov    Dez   Total Origem
# Ford    14324  10088  167679    EUA
# Nissan  22737  13297  154569  Japão
# Toyota  20750   7614  170567  Japão

# %% [markdown]
# ### Preenchendo valores nulos

# %%
carros
# Out:
#               Jan    Fev    Mar    Abr    Mai    Jun    Jul    Ago    Set  \
# Fiat         9010  12156   8030   8855  18181  20524  18287   9715  17724
# Pegeout     13876   6141  11351  14030  12541  10384  17910  15504  11475
# Volkswagem   6024  18034  17542  12640  13601  23627   3498   3939  15367
# Ford        18420  21022  21407   6741   9503  15975  23638  10936  11418
# Nissan       3175   9327  19704   3490  15742   4757  19639   6129  12241
# Toyota      12229  20861  10406  20532  13924   8232  19126  21741   5566
# Chevrolet    8227  21870  19001   5024  24894  11669   8013  18035  20497
#
#               Out    Nov    Dez   Total    Origem
# Fiat        17014   5080   5801  150377    Italia
# Pegeout      8265   7336   5813  134626    França
# Volkswagem   8502   4892   7318  134984  Alemanha
# Ford         4207  14324  10088  167679       EUA
# Nissan      24331  22737  13297  154569     Japão
# Toyota       9586  20750   7614  170567     Japão
# ...

# %%
carros.columns
# Out:
# Index(['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out',
#        'Nov', 'Dez', 'Total', 'Origem'],
#       dtype='object')

# %%
carros_numerico = carros[['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out',
       'Nov', 'Dez', 'Total']]

# %%
# Criando um DataFrame novo e selecionando uma condição
novo_carros = carros_numerico[carros_numerico > 18000]
novo_carros
# Out:
#                 Jan      Fev      Mar      Abr      Mai      Jun      Jul  \
# Fiat            NaN      NaN      NaN      NaN  18181.0  20524.0  18287.0
# Pegeout         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# Volkswagem      NaN  18034.0      NaN      NaN      NaN  23627.0      NaN
# Ford        18420.0  21022.0  21407.0      NaN      NaN      NaN  23638.0
# Nissan          NaN      NaN  19704.0      NaN      NaN      NaN  19639.0
# Toyota          NaN  20861.0      NaN  20532.0      NaN      NaN  19126.0
# Chevrolet       NaN  21870.0  19001.0      NaN  24894.0      NaN      NaN
#
#                 Ago      Set      Out      Nov  Dez   Total
# Fiat            NaN      NaN      NaN      NaN  NaN  150377
# Pegeout         NaN      NaN      NaN      NaN  NaN  134626
# Volkswagem      NaN      NaN      NaN      NaN  NaN  134984
# Ford            NaN      NaN      NaN      NaN  NaN  167679
# Nissan          NaN      NaN  24331.0  22737.0  NaN  154569
# ...

# %%
novo_carros = novo_carros.fillna(9)
novo_carros
# Out:
#                 Jan      Fev      Mar      Abr      Mai      Jun      Jul  \
# Fiat            9.0      9.0      9.0      9.0  18181.0  20524.0  18287.0
# Pegeout         9.0      9.0      9.0      9.0      9.0      9.0      9.0
# Volkswagem      9.0  18034.0      9.0      9.0      9.0  23627.0      9.0
# Ford        18420.0  21022.0  21407.0      9.0      9.0      9.0  23638.0
# Nissan          9.0      9.0  19704.0      9.0      9.0      9.0  19639.0
# Toyota          9.0  20861.0      9.0  20532.0      9.0      9.0  19126.0
# Chevrolet       9.0  21870.0  19001.0      9.0  24894.0      9.0      9.0
#
#                 Ago      Set      Out      Nov  Dez   Total
# Fiat            9.0      9.0      9.0      9.0  9.0  150377
# Pegeout         9.0      9.0      9.0      9.0  9.0  134626
# Volkswagem      9.0      9.0      9.0      9.0  9.0  134984
# Ford            9.0      9.0      9.0      9.0  9.0  167679
# Nissan          9.0      9.0  24331.0  22737.0  9.0  154569
# ...

# %% [markdown]
# ### Eliminando valores nulos

# %%
novo_carros_drop = carros_numerico[carros_numerico < 21000]
novo_carros_drop
# Out:
#               Jan      Fev      Mar    Abr      Mai      Jun      Jul  \
# Fiat         9010  12156.0   8030.0   8855  18181.0  20524.0  18287.0
# Pegeout     13876   6141.0  11351.0  14030  12541.0  10384.0  17910.0
# Volkswagem   6024  18034.0  17542.0  12640  13601.0      NaN   3498.0
# Ford        18420      NaN      NaN   6741   9503.0  15975.0      NaN
# Nissan       3175   9327.0  19704.0   3490  15742.0   4757.0  19639.0
# Toyota      12229  20861.0  10406.0  20532  13924.0   8232.0  19126.0
# Chevrolet    8227      NaN  19001.0   5024      NaN  11669.0   8013.0
#
#                 Ago    Set      Out      Nov    Dez  Total
# Fiat         9715.0  17724  17014.0   5080.0   5801    NaN
# Pegeout     15504.0  11475   8265.0   7336.0   5813    NaN
# Volkswagem   3939.0  15367   8502.0   4892.0   7318    NaN
# Ford        10936.0  11418   4207.0  14324.0  10088    NaN
# Nissan       6129.0  12241      NaN      NaN  13297    NaN
# ...

# %%
novo_carros_drop.dropna()
# Out:
# Empty DataFrame
# Columns: [Jan, Fev, Mar, Abr, Mai, Jun, Jul, Ago, Set, Out, Nov, Dez, Total]
# Index: []

# %%
novo_carros_drop.dropna(axis=1)
# Out:
#               Jan    Abr    Set    Dez
# Fiat         9010   8855  17724   5801
# Pegeout     13876  14030  11475   5813
# Volkswagem   6024  12640  15367   7318
# Ford        18420   6741  11418  10088
# Nissan       3175   3490  12241  13297
# Toyota      12229  20532   5566   7614
# Chevrolet    8227   5024  20497   8641

# %% [markdown]
# ### Verificando quantos valores nulos existem

# %%
novo_carros_drop.isnull().sum()
# Out:
# Jan      0
# Fev      2
# Mar      1
# Abr      0
# Mai      1
# Jun      1
# Jul      1
# Ago      1
# Set      0
# Out      1
# Nov      1
# Dez      0
# Total    7
# dtype: int64

# %% [markdown]
# ### Seleção condicional

# %%
carros
# Out:
#               Jan    Fev    Mar    Abr    Mai    Jun    Jul    Ago    Set  \
# Fiat         9010  12156   8030   8855  18181  20524  18287   9715  17724
# Pegeout     13876   6141  11351  14030  12541  10384  17910  15504  11475
# Volkswagem   6024  18034  17542  12640  13601  23627   3498   3939  15367
# Ford        18420  21022  21407   6741   9503  15975  23638  10936  11418
# Nissan       3175   9327  19704   3490  15742   4757  19639   6129  12241
# Toyota      12229  20861  10406  20532  13924   8232  19126  21741   5566
# Chevrolet    8227  21870  19001   5024  24894  11669   8013  18035  20497
#
#               Out    Nov    Dez   Total    Origem
# Fiat        17014   5080   5801  150377    Italia
# Pegeout      8265   7336   5813  134626    França
# Volkswagem   8502   4892   7318  134984  Alemanha
# Ford         4207  14324  10088  167679       EUA
# Nissan      24331  22737  13297  154569     Japão
# Toyota       9586  20750   7614  170567     Japão
# ...

# %%
carros[carros['Fev'] == 18114]
# Out:
# Empty DataFrame
# Columns: [Jan, Fev, Mar, Abr, Mai, Jun, Jul, Ago, Set, Out, Nov, Dez, Total, Origem]
# Index: []

# %%
carros[carros['Jul'] >= 12000]
# Out:
#            Jan    Fev    Mar    Abr    Mai    Jun    Jul    Ago    Set    Out  \
# Fiat      9010  12156   8030   8855  18181  20524  18287   9715  17724  17014
# Pegeout  13876   6141  11351  14030  12541  10384  17910  15504  11475   8265
# Ford     18420  21022  21407   6741   9503  15975  23638  10936  11418   4207
# Nissan    3175   9327  19704   3490  15742   4757  19639   6129  12241  24331
# Toyota   12229  20861  10406  20532  13924   8232  19126  21741   5566   9586
#
#            Nov    Dez   Total  Origem
# Fiat      5080   5801  150377  Italia
# Pegeout   7336   5813  134626  França
# Ford     14324  10088  167679     EUA
# Nissan   22737  13297  154569   Japão
# Toyota   20750   7614  170567   Japão

# %%
carros[carros['Dez'] == carros['Dez'].max()]
# Out:
#          Jan   Fev    Mar   Abr    Mai   Jun    Jul   Ago    Set    Out  \
# Nissan  3175  9327  19704  3490  15742  4757  19639  6129  12241  24331
#
#           Nov    Dez   Total Origem
# Nissan  22737  13297  154569  Japão

# %%
carros[(carros['Mar'] < 9000 ) | (carros['Out'] >= 20000)]
# Out:
#          Jan    Fev    Mar   Abr    Mai    Jun    Jul   Ago    Set    Out  \
# Fiat    9010  12156   8030  8855  18181  20524  18287  9715  17724  17014
# Nissan  3175   9327  19704  3490  15742   4757  19639  6129  12241  24331
#
#           Nov    Dez   Total  Origem
# Fiat     5080   5801  150377  Italia
# Nissan  22737  13297  154569   Japão

# %%
carros[(carros['Mar'] < 9000 ) & (carros['Out'] >= 20000)]
# Out:
# Empty DataFrame
# Columns: [Jan, Fev, Mar, Abr, Mai, Jun, Jul, Ago, Set, Out, Nov, Dez, Total, Origem]
# Index: []

# %% [markdown]
# ### Valores Máximos e Mínimos

# %%
carros['Set'].max()
# Out:
# 20497

# %%
carros['Set'].argmax()
# Out:
# 6

# %%
carros['Set'].min()
# Out:
# 5566

# %%
carros['Set'].argmin()
# Out:
# 5

# %% [markdown]
# ### Manipulando o Index

# %%
carros
# Out:
#               Jan    Fev    Mar    Abr    Mai    Jun    Jul    Ago    Set  \
# Fiat         9010  12156   8030   8855  18181  20524  18287   9715  17724
# Pegeout     13876   6141  11351  14030  12541  10384  17910  15504  11475
# Volkswagem   6024  18034  17542  12640  13601  23627   3498   3939  15367
# Ford        18420  21022  21407   6741   9503  15975  23638  10936  11418
# Nissan       3175   9327  19704   3490  15742   4757  19639   6129  12241
# Toyota      12229  20861  10406  20532  13924   8232  19126  21741   5566
# Chevrolet    8227  21870  19001   5024  24894  11669   8013  18035  20497
#
#               Out    Nov    Dez   Total    Origem
# Fiat        17014   5080   5801  150377    Italia
# Pegeout      8265   7336   5813  134626    França
# Volkswagem   8502   4892   7318  134984  Alemanha
# Ford         4207  14324  10088  167679       EUA
# Nissan      24331  22737  13297  154569     Japão
# Toyota       9586  20750   7614  170567     Japão
# ...

# %%
# Mantendo o Index anterior
carros.reset_index()
# Out:
#         index    Jan    Fev    Mar    Abr    Mai    Jun    Jul    Ago    Set  \
# 0        Fiat   9010  12156   8030   8855  18181  20524  18287   9715  17724
# 1     Pegeout  13876   6141  11351  14030  12541  10384  17910  15504  11475
# 2  Volkswagem   6024  18034  17542  12640  13601  23627   3498   3939  15367
# 3        Ford  18420  21022  21407   6741   9503  15975  23638  10936  11418
# 4      Nissan   3175   9327  19704   3490  15742   4757  19639   6129  12241
# 5      Toyota  12229  20861  10406  20532  13924   8232  19126  21741   5566
# 6   Chevrolet   8227  21870  19001   5024  24894  11669   8013  18035  20497
#
#      Out    Nov    Dez   Total    Origem
# 0  17014   5080   5801  150377    Italia
# 1   8265   7336   5813  134626    França
# 2   8502   4892   7318  134984  Alemanha
# 3   4207  14324  10088  167679       EUA
# 4  24331  22737  13297  154569     Japão
# 5   9586  20750   7614  170567     Japão
# 6  12423  17169   8641  175463       EUA

# %%
# Excluindo o Index anterior
carros.reset_index(drop=True, inplace=True)

# %%
# Adicionando Marcas
carros_novos = ['Ferrari', 'BMW', 'Mercedez', 'Audi', 'Cadilac', 'Mustang', 'Bugatti']
carros['Novos Carros'] = carros_novos

# Adicionando Nacionalidade das Marcas
nacionalidade_marcas = ['Italia', 'Alemanha', 'Alemanha', 'Alemanha', 'EUA', 'EUA', 'Italia']
carros['Origem'] = nacionalidade_marcas

# %%
carros
# Out:
#      Jan    Fev    Mar    Abr    Mai    Jun    Jul    Ago    Set    Out  \
# 0   9010  12156   8030   8855  18181  20524  18287   9715  17724  17014
# 1  13876   6141  11351  14030  12541  10384  17910  15504  11475   8265
# 2   6024  18034  17542  12640  13601  23627   3498   3939  15367   8502
# 3  18420  21022  21407   6741   9503  15975  23638  10936  11418   4207
# 4   3175   9327  19704   3490  15742   4757  19639   6129  12241  24331
# 5  12229  20861  10406  20532  13924   8232  19126  21741   5566   9586
# 6   8227  21870  19001   5024  24894  11669   8013  18035  20497  12423
#
#      Nov    Dez   Total    Origem Novos Carros
# 0   5080   5801  150377    Italia      Ferrari
# 1   7336   5813  134626  Alemanha          BMW
# 2   4892   7318  134984  Alemanha     Mercedez
# 3  14324  10088  167679  Alemanha         Audi
# 4  22737  13297  154569       EUA      Cadilac
# 5  20750   7614  170567       EUA      Mustang
# 6  17169   8641  175463    Italia      Bugatti

# %%
carros = carros.set_index('Novos Carros')
carros
# Out:
#                 Jan    Fev    Mar    Abr    Mai    Jun    Jul    Ago    Set  \
# Novos Carros
# Ferrari        9010  12156   8030   8855  18181  20524  18287   9715  17724
# BMW           13876   6141  11351  14030  12541  10384  17910  15504  11475
# Mercedez       6024  18034  17542  12640  13601  23627   3498   3939  15367
# Audi          18420  21022  21407   6741   9503  15975  23638  10936  11418
# Cadilac        3175   9327  19704   3490  15742   4757  19639   6129  12241
# Mustang       12229  20861  10406  20532  13924   8232  19126  21741   5566
# Bugatti        8227  21870  19001   5024  24894  11669   8013  18035  20497
#
#                 Out    Nov    Dez   Total    Origem
# Novos Carros
# Ferrari       17014   5080   5801  150377    Italia
# BMW            8265   7336   5813  134626  Alemanha
# Mercedez       8502   4892   7318  134984  Alemanha
# Audi           4207  14324  10088  167679  Alemanha
# Cadilac       24331  22737  13297  154569       EUA
# ...

# %% [markdown]
# ### Agrupando o DataFrame

# %%
agrupado = carros.groupby(['Origem'])
agrupado

# %%
agrupado.describe()
# Out:
#            Jan                                                                 \
#          count          mean          std     min      25%      50%       75%
# Origem
# Alemanha   3.0  12773.333333  6271.133018  6024.0  9950.00  13876.0  16148.00
# EUA        2.0   7702.000000  6402.144797  3175.0  5438.50   7702.0   9965.50
# Italia     2.0   8618.500000   553.664610  8227.0  8422.75   8618.5   8814.25
#
#                     Fev                ...       Dez          Total            \
#               max count          mean  ...       75%      max count      mean
# Origem                                 ...
# Alemanha  18420.0   3.0  15065.666667  ...   8703.00  10088.0   3.0  145763.0
# EUA       12229.0   2.0  15094.000000  ...  11876.25  13297.0   2.0  162568.0
# Italia     9010.0   2.0  17013.000000  ...   7931.00   8641.0   2.0  162920.0
#
#
#                    std       min       25%       50%       75%       max
# Origem
# ...

# %%
agrupado.max()
# Out:
#             Jan    Fev    Mar    Abr    Mai    Jun    Jul    Ago    Set  \
# Origem
# Alemanha  18420  21022  21407  14030  13601  23627  23638  15504  15367
# EUA       12229  20861  19704  20532  15742   8232  19639  21741  12241
# Italia     9010  21870  19001   8855  24894  20524  18287  18035  20497
#
#             Out    Nov    Dez   Total
# Origem
# Alemanha   8502  14324  10088  167679
# EUA       24331  22737  13297  170567
# Italia    17014  17169   8641  175463

# %%
agrupado.min()
# Out:
#            Jan    Fev    Mar   Abr    Mai    Jun    Jul   Ago    Set    Out  \
# Origem
# Alemanha  6024   6141  11351  6741   9503  10384   3498  3939  11418   4207
# EUA       3175   9327  10406  3490  13924   4757  19126  6129   5566   9586
# Italia    8227  12156   8030  5024  18181  11669   8013  9715  17724  12423
#
#             Nov   Dez   Total
# Origem
# Alemanha   4892  5813  134626
# EUA       20750  7614  154569
# Italia     5080  5801  150377

# %%
agrupado.mean()
# Out:
#                    Jan           Fev           Mar      Abr           Mai  \
# Origem
# Alemanha  12773.333333  15065.666667  16766.666667  11137.0  11881.666667
# EUA        7702.000000  15094.000000  15055.000000  12011.0  14833.000000
# Italia     8618.500000  17013.000000  13515.500000   6939.5  21537.500000
#
#               Jun           Jul           Ago           Set           Out  \
# Origem
# Alemanha  16662.0  15015.333333  10126.333333  12753.333333   6991.333333
# EUA        6494.5  19382.500000  13935.000000   8903.500000  16958.500000
# Italia    16096.5  13150.000000  13875.000000  19110.500000  14718.500000
#
#                    Nov           Dez   Total
# Origem
# Alemanha   8850.666667   7739.666667  145763
# EUA       21743.500000  10455.500000  162568
# Italia    11124.500000   7221.000000  162920

# %%
agrupado2 = carros.groupby(['Origem']).mean()
agrupado2
# Out:
#                    Jan           Fev           Mar      Abr           Mai  \
# Origem
# Alemanha  12773.333333  15065.666667  16766.666667  11137.0  11881.666667
# EUA        7702.000000  15094.000000  15055.000000  12011.0  14833.000000
# Italia     8618.500000  17013.000000  13515.500000   6939.5  21537.500000
#
#               Jun           Jul           Ago           Set           Out  \
# Origem
# Alemanha  16662.0  15015.333333  10126.333333  12753.333333   6991.333333
# EUA        6494.5  19382.500000  13935.000000   8903.500000  16958.500000
# Italia    16096.5  13150.000000  13875.000000  19110.500000  14718.500000
#
#                    Nov           Dez   Total
# Origem
# Alemanha   8850.666667   7739.666667  145763
# EUA       21743.500000  10455.500000  162568
# Italia    11124.500000   7221.000000  162920

# %% [markdown]
# ---

# %% [markdown]
# ## Concat

# %%
carros
# Out:
#                 Jan    Fev    Mar    Abr    Mai    Jun    Jul    Ago    Set  \
# Novos Carros
# Ferrari        9010  12156   8030   8855  18181  20524  18287   9715  17724
# BMW           13876   6141  11351  14030  12541  10384  17910  15504  11475
# Mercedez       6024  18034  17542  12640  13601  23627   3498   3939  15367
# Audi          18420  21022  21407   6741   9503  15975  23638  10936  11418
# Cadilac        3175   9327  19704   3490  15742   4757  19639   6129  12241
# Mustang       12229  20861  10406  20532  13924   8232  19126  21741   5566
# Bugatti        8227  21870  19001   5024  24894  11669   8013  18035  20497
#
#                 Out    Nov    Dez   Total    Origem
# Novos Carros
# Ferrari       17014   5080   5801  150377    Italia
# BMW            8265   7336   5813  134626  Alemanha
# Mercedez       8502   4892   7318  134984  Alemanha
# Audi           4207  14324  10088  167679  Alemanha
# Cadilac       24331  22737  13297  154569       EUA
# ...

# %%
acidentes = pd.DataFrame(np.random.randint(50, 200, size=(7, 12)),
                        ['Ferrari', 'BMW', 'Mercedez', 'Audi', 'Cadilac', 'Mustang', 'Bugatti'],
                        ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez'])
acidentes
# Out:
#           Jan  Fev  Mar  Abr  Mai  Jun  Jul  Ago  Set  Out  Nov  Dez
# Ferrari    71   80  112  137  149  134  180   55  140   57  137   81
# BMW       186   80   87  117   70  174  116   63   68   70   69  129
# Mercedez  172  171  165   59  128  167  154  150   71   74  146   72
# Audi       97  103   52   91   71   79  186  133   80  162   85  182
# Cadilac   145   93  176  139  151   56  135   85  145  176  150   77
# Mustang   114  162   81   52   70  188  141  163  142   61  128  187
# Bugatti   134  195  141  134  182  149  167  109   75   67  133  170

# %%
acidentes['Total'] = acidentes.sum(axis=1)
acidentes
# Out:
#           Jan  Fev  Mar  Abr  Mai  Jun  Jul  Ago  Set  Out  Nov  Dez  Total
# Ferrari    71   80  112  137  149  134  180   55  140   57  137   81   1333
# BMW       186   80   87  117   70  174  116   63   68   70   69  129   1229
# Mercedez  172  171  165   59  128  167  154  150   71   74  146   72   1529
# Audi       97  103   52   91   71   79  186  133   80  162   85  182   1321
# Cadilac   145   93  176  139  151   56  135   85  145  176  150   77   1528
# Mustang   114  162   81   52   70  188  141  163  142   61  128  187   1489
# Bugatti   134  195  141  134  182  149  167  109   75   67  133  170   1656

# %%
pd.concat([carros, acidentes])
# Out:
#             Jan    Fev    Mar    Abr    Mai    Jun    Jul    Ago    Set  \
# Ferrari    9010  12156   8030   8855  18181  20524  18287   9715  17724
# BMW       13876   6141  11351  14030  12541  10384  17910  15504  11475
# Mercedez   6024  18034  17542  12640  13601  23627   3498   3939  15367
# Audi      18420  21022  21407   6741   9503  15975  23638  10936  11418
# Cadilac    3175   9327  19704   3490  15742   4757  19639   6129  12241
# Mustang   12229  20861  10406  20532  13924   8232  19126  21741   5566
# Bugatti    8227  21870  19001   5024  24894  11669   8013  18035  20497
# Ferrari      71     80    112    137    149    134    180     55    140
# BMW         186     80     87    117     70    174    116     63     68
# Mercedez    172    171    165     59    128    167    154    150     71
# Audi         97    103     52     91     71     79    186    133     80
# Cadilac     145     93    176    139    151     56    135     85    145
# ...

# %%
pd.concat([carros, acidentes], axis=1).T
# Out:
#        Ferrari       BMW  Mercedez      Audi Cadilac Mustang Bugatti
# Jan       9010     13876      6024     18420    3175   12229    8227
# Fev      12156      6141     18034     21022    9327   20861   21870
# Mar       8030     11351     17542     21407   19704   10406   19001
# Abr       8855     14030     12640      6741    3490   20532    5024
# Mai      18181     12541     13601      9503   15742   13924   24894
# Jun      20524     10384     23627     15975    4757    8232   11669
# Jul      18287     17910      3498     23638   19639   19126    8013
# Ago       9715     15504      3939     10936    6129   21741   18035
# Set      17724     11475     15367     11418   12241    5566   20497
# Out      17014      8265      8502      4207   24331    9586   12423
# Nov       5080      7336      4892     14324   22737   20750   17169
# Dez       5801      5813      7318     10088   13297    7614    8641
# Total   150377    134626    134984    167679  154569  170567  175463
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Juntando todas as marcas

# %%
carros
# Out:
#                 Jan    Fev    Mar    Abr    Mai    Jun    Jul    Ago    Set  \
# Novos Carros
# Ferrari        9010  12156   8030   8855  18181  20524  18287   9715  17724
# BMW           13876   6141  11351  14030  12541  10384  17910  15504  11475
# Mercedez       6024  18034  17542  12640  13601  23627   3498   3939  15367
# Audi          18420  21022  21407   6741   9503  15975  23638  10936  11418
# Cadilac        3175   9327  19704   3490  15742   4757  19639   6129  12241
# Mustang       12229  20861  10406  20532  13924   8232  19126  21741   5566
# Bugatti        8227  21870  19001   5024  24894  11669   8013  18035  20497
#
#                 Out    Nov    Dez   Total    Origem
# Novos Carros
# Ferrari       17014   5080   5801  150377    Italia
# BMW            8265   7336   5813  134626  Alemanha
# Mercedez       8502   4892   7318  134984  Alemanha
# Audi           4207  14324  10088  167679  Alemanha
# Cadilac       24331  22737  13297  154569       EUA
# ...

# %%
carros_original = pd.DataFrame(np.random.randint(3000, 25000, size=(8,12)), 
                   ['Fiat', 'Pegeout', 'Volkswagem', 'Ford', 'Nissan', 'Toyota', 'Honda', 'Chevrolet'], 
                   ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez'],)


carros_original['Total'] = carros_original.sum(axis=1)


carros_origem = ['Italia', 'França', 'Alemanha', 'EUA', 'Japão', 'Japão', 'Japão', 'EUA']
carros_original['Origem'] = carros_origem

# %%
carros_original
# Out:
#               Jan    Fev    Mar    Abr    Mai    Jun    Jul    Ago    Set  \
# Fiat         7522  16728  11382  18754  14606  11820  22261   3686   7610
# Pegeout      6162   7994   7172  11010  14667  22578  23368  10829  12178
# Volkswagem  18689   6855   6472  18033   9388  17880  10922   9621  15630
# Ford         9852   7114   4144  14651   4456   8559  19255  16965  12024
# Nissan      12485  24355   3899   7356  10828  14575  24523   7412  24057
# Toyota      19862  24188  16587   7900  23619  20692  21311   5867   8644
# Honda       20933   7437  16337   7915   7713  16894  15535  20972   8811
# Chevrolet   13502  11809  20400  13100  24445  23297   3818  23545   4933
#
#               Out    Nov    Dez   Total    Origem
# Fiat        13711  23343  14959  166382    Italia
# Pegeout     11302  14695   8217  150172    França
# Volkswagem  21989   5517  20189  161185  Alemanha
# Ford        19986  11552  10980  139538       EUA
# ...

# %% [markdown]
# ### Concatenando os dois DataFrames

# %%
carros2 = pd.concat([carros, carros_original])
carros2
# Out:
#               Jan    Fev    Mar    Abr    Mai    Jun    Jul    Ago    Set  \
# Ferrari      9010  12156   8030   8855  18181  20524  18287   9715  17724
# BMW         13876   6141  11351  14030  12541  10384  17910  15504  11475
# Mercedez     6024  18034  17542  12640  13601  23627   3498   3939  15367
# Audi        18420  21022  21407   6741   9503  15975  23638  10936  11418
# Cadilac      3175   9327  19704   3490  15742   4757  19639   6129  12241
# Mustang     12229  20861  10406  20532  13924   8232  19126  21741   5566
# Bugatti      8227  21870  19001   5024  24894  11669   8013  18035  20497
# Fiat         7522  16728  11382  18754  14606  11820  22261   3686   7610
# Pegeout      6162   7994   7172  11010  14667  22578  23368  10829  12178
# Volkswagem  18689   6855   6472  18033   9388  17880  10922   9621  15630
# Ford         9852   7114   4144  14651   4456   8559  19255  16965  12024
# Nissan      12485  24355   3899   7356  10828  14575  24523   7412  24057
# ...

# %% [markdown]
# ### Utilizando List Comprehensions e Lambda

# %%
carros2['Sigla List Comprehensions'] = [l[:3].upper() for l in carros2['Origem']]

# %% [markdown]
# carros2['Sigla Lambda Function'] = carros2['Origem'].apply(lambda x: x[:3].upper())

# %%
carros2
# Out:
#               Jan    Fev    Mar    Abr    Mai    Jun    Jul    Ago    Set  \
# Ferrari      9010  12156   8030   8855  18181  20524  18287   9715  17724
# BMW         13876   6141  11351  14030  12541  10384  17910  15504  11475
# Mercedez     6024  18034  17542  12640  13601  23627   3498   3939  15367
# Audi        18420  21022  21407   6741   9503  15975  23638  10936  11418
# Cadilac      3175   9327  19704   3490  15742   4757  19639   6129  12241
# Mustang     12229  20861  10406  20532  13924   8232  19126  21741   5566
# Bugatti      8227  21870  19001   5024  24894  11669   8013  18035  20497
# Fiat         7522  16728  11382  18754  14606  11820  22261   3686   7610
# Pegeout      6162   7994   7172  11010  14667  22578  23368  10829  12178
# Volkswagem  18689   6855   6472  18033   9388  17880  10922   9621  15630
# Ford         9852   7114   4144  14651   4456   8559  19255  16965  12024
# Nissan      12485  24355   3899   7356  10828  14575  24523   7412  24057
# ...

# %% [markdown]
# ### Trocando o nome das colunas

# %%
# Será utilizado para gerar gráfico de pizza

carros3 = carros2.copy()

# %%
carros2.columns
# Out:
# Index(['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out',
#        'Nov', 'Dez', 'Total', 'Origem', 'Sigla List Comprehensions'],
#       dtype='object')

# %%
carros2.columns = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out',
       'Nov', 'Dez', 'Total', 'Origem', 'Sigla']

# %%
carros2.drop(['Origem', 'Sigla', 'Total'], axis = 1, inplace=True)

# %% [markdown]
# ___

# %% [markdown]
# # Tutorial de Matplotlib

# %%
# Criando um novo DataFrame e modificando a forma de visualizar as informações do DF anterior
carros = carros2.T

# %%
carros
# Out:
#      Ferrari    BMW  Mercedez   Audi  Cadilac  Mustang  Bugatti   Fiat  \
# Jan     9010  13876      6024  18420     3175    12229     8227   7522
# Fev    12156   6141     18034  21022     9327    20861    21870  16728
# Mar     8030  11351     17542  21407    19704    10406    19001  11382
# Abr     8855  14030     12640   6741     3490    20532     5024  18754
# Mai    18181  12541     13601   9503    15742    13924    24894  14606
# Jun    20524  10384     23627  15975     4757     8232    11669  11820
# Jul    18287  17910      3498  23638    19639    19126     8013  22261
# Ago     9715  15504      3939  10936     6129    21741    18035   3686
# Set    17724  11475     15367  11418    12241     5566    20497   7610
# Out    17014   8265      8502   4207    24331     9586    12423  13711
# Nov     5080   7336      4892  14324    22737    20750    17169  23343
# Dez     5801   5813      7318  10088    13297     7614     8641  14959
#
# ...

# %%
# Criando uma coluna com valores acumulados de cada marca

for l in carros.columns:
    carros[f'{l} Acumulado'] = carros[l].cumsum()

# %%
carros
# Out:
#      Ferrari    BMW  Mercedez   Audi  Cadilac  Mustang  Bugatti   Fiat  \
# Jan     9010  13876      6024  18420     3175    12229     8227   7522
# Fev    12156   6141     18034  21022     9327    20861    21870  16728
# Mar     8030  11351     17542  21407    19704    10406    19001  11382
# Abr     8855  14030     12640   6741     3490    20532     5024  18754
# Mai    18181  12541     13601   9503    15742    13924    24894  14606
# Jun    20524  10384     23627  15975     4757     8232    11669  11820
# Jul    18287  17910      3498  23638    19639    19126     8013  22261
# Ago     9715  15504      3939  10936     6129    21741    18035   3686
# Set    17724  11475     15367  11418    12241     5566    20497   7610
# Out    17014   8265      8502   4207    24331     9586    12423  13711
# Nov     5080   7336      4892  14324    22737    20750    17169  23343
# Dez     5801   5813      7318  10088    13297     7614     8641  14959
#
# ...

# %% [markdown]
# # Funções

# %%
# Plotando o primeiro gráfico

plt.plot(carros['Mustang Acumulado'], label = 'Vendas de Mustangs')
plt.title('Vendas: Mustang', fontsize=22)
plt.xlabel('Meses', fontsize=16)
plt.ylabel('Unidades Vendidas', fontsize=16)
plt.legend()

# %%
# Criando subplots

plt.subplot(2, 2, 1)
plt.plot(carros['Ferrari Acumulado'])
plt.xticks(rotation=90)

plt.subplot(2, 2, 2)
plt.plot(carros['Fiat Acumulado'])
plt.xticks(rotation=90)

plt.subplot(2, 2, 3)
plt.plot(carros['Ford Acumulado'])
plt.xticks(rotation=90)

plt.subplot(2, 2, 4)
plt.plot(carros['BMW Acumulado'])
plt.xticks(rotation=90)


plt.tight_layout()
plt.show()

# %% [markdown]
# # Orientação a Objetos

# %% [markdown]
# - https://matplotlib.org/3.5.1/gallery/lines_bars_and_markers/linestyles.html
#
# - https://matplotlib.org/3.3.3/api/markers_api.html

# %%
fig = plt.figure()



ax = fig.add_axes([0, 0, 1, 1])
ax.plot(carros['BMW Acumulado'], linestyle='--', color = 'orange', label = 'BMW', linewidth=4, alpha=0.7, marker='v',
       markersize=15, markerfacecolor='red', markeredgewidth=2, markeredgecolor='black')
ax.plot(carros['Audi Acumulado'], linestyle='-.', color = 'navy', label = 'AUDI')
ax.set_title('Comparativo: Audi x BMW', fontsize=22)
ax.set_xlabel('Meses', fontsize=18,)
ax.set_ylabel('Unidades vendidas', fontsize=18)
plt.xticks(rotation=90)
ax.legend()


# -----------------------------------------------------------------------
# Adicionando o gráfico menor
# -----------------------------------------------------------------------


ax2 = fig.add_axes([0.625, 0.1, 0.3, 0.3])
ax2.plot(carros['BMW Acumulado'], linestyle='--', color = 'orange', label = 'BMW')
ax2.plot(carros['Audi Acumulado'], linestyle='-.', color = 'navy', label = 'AUDI')
ax2.set_xlim(['Mar','Jul'])
ax2.set_ylim([50000, 150000])
ax2.set_title('Março - Julho')
plt.xticks(rotation=90)


plt.show()
# Para salvar a figura
fig.savefig('AUDIxBMW.png', dpi=200)

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.plot(carros['BMW Acumulado'], linestyle='--', color = 'orange', label = 'BMW', linewidth=4, alpha=0.7, marker='v',
       markersize=15, markerfacecolor='red', markeredgewidth=2, markeredgecolor='black')
ax.plot(carros['Audi Acumulado'], linestyle='-.', color = 'navy', label = 'AUDI')

ax.set_xlim(['Mar','Out'])
ax.set_ylim([50000, 150000])

ax.set_title('Comparativo: Audi x BMW', fontsize=22)
ax.set_xlabel('Meses', fontsize=18,)
ax.set_ylabel('Unidades vendidas', fontsize=18)
plt.xticks(rotation=90)
ax.legend(loc=2)
plt.show()

# %%
carros.columns
# Out:
# Index(['Ferrari', 'BMW', 'Mercedez', 'Audi', 'Cadilac', 'Mustang', 'Bugatti',
#        'Fiat', 'Pegeout', 'Volkswagem', 'Ford', 'Nissan', 'Toyota', 'Honda',
#        'Chevrolet', 'Ferrari Acumulado', 'BMW Acumulado', 'Mercedez Acumulado',
#        'Audi Acumulado', 'Cadilac Acumulado', 'Mustang Acumulado',
#        'Bugatti Acumulado', 'Fiat Acumulado', 'Pegeout Acumulado',
#        'Volkswagem Acumulado', 'Ford Acumulado', 'Nissan Acumulado',
#        'Toyota Acumulado', 'Honda Acumulado', 'Chevrolet Acumulado'],
#       dtype='object')

# %%
# Scatter Plot

quant = [4650, 6650, 9500, 12528, 16623, 18900, 21654, 23600]
preco = [200000, 170000, 130000, 108000, 91000, 85000, 81235, 75444]

fig, ax = plt.subplots(figsize=(10, 6))
ax.scatter(quant, preco)
ax.set_title('Comparativo: Preço x Quantidade vendida', fontsize=20)
ax.set_xlabel('Quantidade Vendida')
ax.set_ylabel('Preço (R$)')
# Out:
# Text(0, 0.5, 'Preço (R$)')

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize=(10, 5))

ax[1].scatter(quant, preco)
ax[1].set_title('Scatter', fontsize=20)

ax[0].plot(quant, preco)
ax[0].set_title('Linha', fontsize=20)

plt.tight_layout()

# %%
# Gráfico de barras

fig, ax = plt.subplots()
ax.bar(carros.index, carros['Audi'], )
ax.set_title('Gráfico de Barras', fontsize=20)
ax.set_xlabel('Eixo X')
ax.set_ylabel('Eixo Y')
# Out:
# Text(0, 0.5, 'Eixo Y')

# %%
# Gráfico de barras na horizontal

fig, ax = plt.subplots()
ax.barh(carros.index, carros['Audi'], )
ax.set_title('Gráfico de Barras na Horizontal', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Gráfico de Barras na Horizontal')

# %%
carros.columns
# Out:
# Index(['Ferrari', 'BMW', 'Mercedez', 'Audi', 'Cadilac', 'Mustang', 'Bugatti',
#        'Fiat', 'Pegeout', 'Volkswagem', 'Ford', 'Nissan', 'Toyota', 'Honda',
#        'Chevrolet', 'Ferrari Acumulado', 'BMW Acumulado', 'Mercedez Acumulado',
#        'Audi Acumulado', 'Cadilac Acumulado', 'Mustang Acumulado',
#        'Bugatti Acumulado', 'Fiat Acumulado', 'Pegeout Acumulado',
#        'Volkswagem Acumulado', 'Ford Acumulado', 'Nissan Acumulado',
#        'Toyota Acumulado', 'Honda Acumulado', 'Chevrolet Acumulado'],
#       dtype='object')

# %%
carros[['Ferrari', 'BMW', 'Mercedez', 'Audi', 'Cadilac', 'Mustang', 'Bugatti',
       'Fiat', 'Pegeout', 'Volkswagem', 'Ford', 'Nissan', 'Toyota', 'Honda',
       'Chevrolet']].plot(kind='bar', subplots=True, figsize=(20, 60))
plt.show()

# %%
# Histograma

x = np.random.randn(10000)
fig, ax = plt.subplots()
ax.hist(x, bins=20)
ax.set_title('Histograma', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Histograma')

# %% [markdown]
# ---

# %%
# Gráfico de pizza

carros3
# Out:
#               Jan    Fev    Mar    Abr    Mai    Jun    Jul    Ago    Set  \
# Ferrari      9010  12156   8030   8855  18181  20524  18287   9715  17724
# BMW         13876   6141  11351  14030  12541  10384  17910  15504  11475
# Mercedez     6024  18034  17542  12640  13601  23627   3498   3939  15367
# Audi        18420  21022  21407   6741   9503  15975  23638  10936  11418
# Cadilac      3175   9327  19704   3490  15742   4757  19639   6129  12241
# Mustang     12229  20861  10406  20532  13924   8232  19126  21741   5566
# Bugatti      8227  21870  19001   5024  24894  11669   8013  18035  20497
# Fiat         7522  16728  11382  18754  14606  11820  22261   3686   7610
# Pegeout      6162   7994   7172  11010  14667  22578  23368  10829  12178
# Volkswagem  18689   6855   6472  18033   9388  17880  10922   9621  15630
# Ford         9852   7114   4144  14651   4456   8559  19255  16965  12024
# Nissan      12485  24355   3899   7356  10828  14575  24523   7412  24057
# ...

# %%
carros3['Origem'].value_counts().plot.pie(explode = [0, 0, 0.1, 0, 0], autopct = '%0.2f%%')
# Out:
# <AxesSubplot:ylabel='Origem'>
